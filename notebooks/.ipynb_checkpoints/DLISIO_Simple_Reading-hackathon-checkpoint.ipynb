# %% [markdown]
# # Finding Image Logs

# %% [markdown]
# ## Go find them!

# %%
# %matplotlib inline

import os
import pandas as pd
import dlisio
import matplotlib.pyplot as plt
import numpy as np
import numpy.lib.recfunctions as rfn

# %%
folderpath = r"C:\Users\aruss\Documents\FORCE Data"

# %% [markdown]
# #### Assumptions: Data is compiled into static and dynamic images (no individual pads only)

# %%
def df_column_uniquify(df):
    df_columns = df.columns
    new_columns = []
    for item in df_columns:
        counter = 0
        newitem = item
        while newitem in new_columns:
            counter += 1
            newitem = "{}_{}".format(item, counter)
        new_columns.append(newitem)
    df.columns = new_columns
    return df

# %%
def givemeimages(channel,d):
    curves = channel.curves()
    print(curves.shape)
    if curves.shape[0]>24:
        dynamic_curve = curves
    for channel in d.channels:
        curvename = channel.name
        if "STAT" in curvename:
            curves = channel.curves()
            if cruves.shape[0]>24:
                static_curve = curves
        if "GR" in curvename:
            gr_curve = channel.curves()
        if "TDEP" in curvename:
            depth_curve = channel.curves()
    df = pd.DataFrame(np.hstack((depth_curve[:,None], dynamic_curve[:,None], static_curve[:,None], gr_curve[:,None])))
    return df

# %%
well_list_both = []
well_list_yestech_nodyn = []
well_list_onlycurve = []
well_list_notech_nodyn = []
df_list = []
curves_name = []

for (root, dirs, files) in os.walk(folderpath):
    for f in files:
        filepath = os.path.join(root, f)
        if filepath.endswith('.' + 'dlis') or filepath.endswith('.' + 'DLIS'):
            print(filepath)
            try:
                curves_list = []
                curves_name = []
                with dlisio.load(filepath) as file:
                    for d in file:
                        for origin in d.origins:
                            #created = origin.attic.get('PRODUCT')[0]
                            created = origin.product
                            wellname = origin.well_name
                            if "Techlog" in created:
                                for channel in d.channels:
                                    curvename = channel.name
                                    if "DYN" in curvename:
                                        #wellname = origin.attic.get('WELL-NAME')[0]
                                        well_list_both.append(wellname) 
                                        for channel in d.channels:
                                            curves_name.append(channel.name)
                                            curves = channel.curves()
                                            curves_list.append(curves)
                                    else:
                                        #wellname = origin.attic.get('WELL-NAME')[0]
                                        well_list_yestech_nodyn.append(wellname) 
                            else:
                                for channel in d.channels:
                                    curvename = channel.name
                                    if "DYN" in curvename:
                                        #wellname = origin.attic.get('WELL-NAME')[0]
                                        well_list_onlycurve.append(wellname)                            
                                        curve_list.append(channel.name)
                                        for channel in d.channels:
                                            curves_name.append(channel.name)
                                            curves = channel.curves()
                                            curves_list.append(curves)
                                    else:
                                        #wellname = origin.attic.get('WELL-NAME')[0]
                                        well_list_notech_nodyn.append(wellname)
                df_name = wellname + "_df"
                df_name = pd.DataFrame()
                name_index = 0
                for c in curves_L:
                    name = curves_name[name_index]
                    np.vstack(c)
                    try:
                        num_col = c.shape[1]
                        col_name = [name] * num_col
                        df = pd.DataFrame(data=c, columns=col_name)
                        name_index = name_index + 1
                        df = df_column_uniquify(df)
                        curve_df = pd.concat([curve_df, df], axis=1)
                    except:
                        num_col = 0
                        df = pd.DataFrame(data=c, columns=[name])
                        name_index = name_index + 1
                        curve_df = pd.concat([curve_df, df], axis=1)
                        continue
                curve_df["Wellname"] = wellname
                df_list.append(df_name)
            except:
                print("cannot read filepath " + filepath)
                continue
# Out:
# C:\Users\aruss\Documents\FORCE Data\Audacious 1\MainLogFmiDsi_play_189.dlis
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD2_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD1_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC2_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC1_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB2_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB1_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA2_CV-O.21-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (105). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA1_CV-O.21-C.0
# WARNING:root:continuing with the last object
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBD2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBD1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBC2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBC1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBA2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBA1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FB00 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB4A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB3A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB2A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB1A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB4 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB3 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object DB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object FB00 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB4A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB3A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB2A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB1A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB4 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB3 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.2) referenced from object DB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAD_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAD_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAC_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAC_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAB_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAB_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAA_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FBAA_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCD2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCD2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCD1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCD1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCC2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCC2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCC1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCC1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCB2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCB1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCA2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCA2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCA1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.21-C.1) referenced from object FCA1 of class <class 'dlisio.plumbing.channel.Channel'>
# cannot read filepath C:\Users\aruss\Documents\FORCE Data\Audacious 1\MainLogFmiDsi_play_189.dlis
# C:\Users\aruss\Documents\FORCE Data\Audacious 1\RepeatSectionFmiDsi_play_211.dlis
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD2_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD1_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC2_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC1_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB2_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB1_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA2_CV-O.38-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (102). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA1_CV-O.38-C.0
# WARNING:root:continuing with the last object
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBD2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBD1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBC2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBC1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBA2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBA1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FB00 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB4A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB3A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB2A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB1A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB4 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB3 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object DB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object FB00 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB4A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB3A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB2A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB1A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB4 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB3 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.2) referenced from object DB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAD_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAD_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAC_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAC_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAB_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAB_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAA_P of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FBAA_A of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCD2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCD2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCD1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCD1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCC2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCC2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCC1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCC1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCB2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCB2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCB1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCB1 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCA2_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCA2 of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCA1_CV of class <class 'dlisio.plumbing.channel.Channel'>
# WARNING:root:missing attribute 'source' dlisio.core.objref(fingerprint=T.TOOL-I.FBSTB-O.38-C.1) referenced from object FCA1 of class <class 'dlisio.plumbing.channel.Channel'>
# cannot read filepath C:\Users\aruss\Documents\FORCE Data\Audacious 1\RepeatSectionFmiDsi_play_211.dlis
# C:\Users\aruss\Documents\FORCE Data\Audacious 3\AUDACIOUS3_FMI_DSI_HNGS.DLIS
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FB00-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1A-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB4-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB3-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB2-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.DB1-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD2_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCD1_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC2_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCC1_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB2_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCB1_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA2_CV-O.24-C.0
# WARNING:root:continuing with the last object
# ERROR:root:multiple distinct objects in set 440-OP-CHANNEL (362). Duplicate fingerprint = T.440-OP-CHANNEL-I.FCA1_CV-O.24-C.0
# WARNING:root:continuing with the last object
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='SDEVM', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='HAZIM', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='GSW', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='GNV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='GPV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='GADZ', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RB_GPIT', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='P1AZ_GPIT', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='PP', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_DCXV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_DCXI', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='XGMO', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRSLH', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRSLL', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='DFCHV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCHV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRLA', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRHD', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRHA', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FSVD', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FSVC', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FSVB', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FSVA', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FSVL', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FRLD', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FCTS', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCIR', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCBS', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCVN', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCVP', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCV0', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCVL', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FXSP', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FEPC', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='DCHV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCV2', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCV1', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCEV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FFRE', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_FNOR_LOW', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_FNOR_HIGH', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_ANOR_LOW', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_ANOR_HIGH', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_CS_HIGH', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_IMAGE_WIDTH', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='U-FBST_FBAV_LOW', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='P1AZ_FBST', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RB_FBST', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='DEVIM', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='SWFB', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RC2', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RC1', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FBDC', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='AEDI', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FB00', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FB90', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FBCR', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FBAV', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EV90', origin=24, copynum=0) referenced from object FBSTB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EETS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EETP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EERS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EERP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='EER1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TETS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TETP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TERS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TERP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TER1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='CETS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='CETP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='CERS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='CERP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='CER1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='ENTS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='ENTP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='ENRS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='ENRP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='ENR1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TTTS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TTTP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TTRS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TTRP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='TTR1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='LFTS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='LFTP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='LFRS', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='LFRP', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='LFR1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='E2T4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='E2R4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='E2R1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='T2T4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='T2R4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='T2R1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='C2T4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='C2R4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='C2R1', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='E1T4', origin=24, copynum=0) referenced from object DSST-B of class <class 'dlisio.plumbing.tool.Tool'>
# ...
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='QGRPRES', origin=1061437721, copynum=0) referenced from object CQG_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='RAZ_EDTC', origin=544367975, copynum=0) referenced from object EDTC-B_MEMORY_DATA of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_B', origin=30, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_A', origin=843471969, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_H', origin=544367975, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_C', origin=843471969, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_D', origin=1062554975, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_F', origin=113, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_E', origin=1061886208, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_G', origin=859385923, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='CDF', origin=612285714, copynum=1) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='DF', origin=30, copynum=0) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPRPRES', origin=1061314386, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPTEMP', origin=1059651871, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPBTEMP', origin=843471969, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELTEMP', origin=122, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELBTEMP', origin=64, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPACOM', origin=927083826, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELPRES', origin=544367975, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# cannot read filepath C:\Users\aruss\Documents\FORCE Data\Barossa 3\S1R2_PPC-SSCAN-NGI-XPT-GR-ECRD\XPT_Pretest_DLIS\COP_WL_Barossa-3_S1R2_XPT_8_4045.89m.dlis
# C:\Users\aruss\Documents\FORCE Data\Barossa 3\S1R2_PPC-SSCAN-NGI-XPT-GR-ECRD\XPT_Pretest_DLIS\COP_WL_Barossa-3_S1R2_XPT_9_4058.08m.dlis
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCAX', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCAY', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='FCAZ', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RCFCAX', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RCFCAY', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'channels' dlisio.core.obname(id='RCFCAZ', origin=0, copynum=0) referenced from object NGIT-BB of class <class 'dlisio.plumbing.tool.Tool'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_H', origin=1023779724, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_F', origin=1023842028, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_B', origin=3539011, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_A', origin=1023757260, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_D', origin=879418001, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_C', origin=1023890364, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_G', origin=0, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_E', origin=1023771420, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='HYDRPRES', origin=603543568, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='HYDBTEMP', origin=1062162004, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='HYDTEMP', origin=616718550, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='HYDACOM', origin=0, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='HYDTELPRES', origin=1023711948, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='HYDTELBTEMP', origin=1023748572, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='HYDTELTEMP', origin=1062029151, copynum=0) referenced from object SAPPHIRE_HYDROSTATIC_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='CDF', origin=1023703452, copynum=1) referenced from object HTEN_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='DF', origin=4390957, copynum=0) referenced from object HTEN_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='UFX', origin=1062424645, copynum=0) referenced from object GPIT-F_MAGNETOMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='UFZ', origin=1023845052, copynum=0) referenced from object GPIT-F_MAGNETOMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='UFY', origin=1062225219, copynum=1) referenced from object GPIT-F_MAGNETOMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='CDF', origin=1023703452, copynum=1) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='DF', origin=4390957, copynum=0) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='FCOUAX', origin=0, copynum=0) referenced from object GPIT-F_ACCELEROMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='FCOUAY', origin=699543280, copynum=0) referenced from object GPIT-F_ACCELEROMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='FCOUAZ', origin=0, copynum=0) referenced from object GPIT-F_ACCELEROMETERS_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='QGTEMP', origin=1061253376, copynum=0) referenced from object CQG_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='QGRPRES', origin=1023751596, copynum=0) referenced from object CQG_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='RAZ_EDTC', origin=0, copynum=0) referenced from object EDTC-B_MEMORY_DATA of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_B', origin=3539011, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_A', origin=1023757260, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_H', origin=1023779724, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_C', origin=1023890364, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_D', origin=879418001, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_F', origin=1023842028, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_E', origin=1023771420, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='RADIUS_G', origin=0, copynum=0) referenced from object NGI_CALIPER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='CDF', origin=1023703452, copynum=1) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='DF', origin=4390957, copynum=0) referenced from object HTEN_BEFORE_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPRPRES', origin=1023666636, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPTEMP', origin=1023689292, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'calibrated' dlisio.core.obname(id='SAPBTEMP', origin=1023796908, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELTEMP', origin=0, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELBTEMP', origin=511842702, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPACOM', origin=489803190, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# WARNING:root:missing attribute 'uncalibrated' dlisio.core.obname(id='SAPTELPRES', origin=1023819564, copynum=0) referenced from object SAPPHIRE_FORMATION_MASTER_CALIBRATION of class <class 'dlisio.plumbing.calibration.Calibration'>
# cannot read filepath C:\Users\aruss\Documents\FORCE Data\Barossa 3\S1R2_PPC-SSCAN-NGI-XPT-GR-ECRD\XPT_Pretest_DLIS\COP_WL_Barossa-3_S1R2_XPT_9_4058.08m.dlis
# C:\Users\aruss\Documents\FORCE Data\Barossa 5\Quanta_Geo_Processed\Data\Bar_5A_S1R2_QG_Processed_L007UP_Full_Images_Repeat2.dlis
# cannot read filepath C:\Users\aruss\Documents\FORCE Data\Barossa 5\Quanta_Geo_Processed\Data\Bar_5A_S1R2_QG_Processed_L007UP_Full_Images_Repeat2.dlis
# C:\Users\aruss\Documents\FORCE Data\Barossa 5\Quanta_Geo_Processed\Data\COP_Barossa-5A_S1R2_Quanta Geo_Processed_L003UP_with_Full-Images.dlis

# %%
df

# %%
print(set(well_list_both))
print(set(well_list_yestech_nodyn))
print(set(well_list_onlycurve))
print(set(well_list_notech_nodyn))

# %%
results=pd.DataFrame(
    {'path': filepath_list,
     'Curve': curvename,
     'Long': descriptions,
     'Unit': unit,
     'Program': program,
     'Wellname' : well,
     'File_ids': file_ids,
     'Created_by' : created
    })

# %%
results

# %%
results['Wellname'] = results.Wellname.str.upper()

# %%
results.Wellname.unique()

# %%
results.to_csv("C:\\Users\\aruss\\Documents\\FORCE Data\\results.csv")

# %% [markdown]
# ### You can work with a single file using the cell below - or by adding an additional for loop to the code below, you can work through a list of files.  Another option is to use os.walk to get all .dlis files in a parent folder.  Example:
#
#     for (root, dirs, files) in os.walk(folderpath):
#         for f in files:
#             filepath = os.path.join(root, f)
#             if filepath.endswith('.' + 'dlis'):
#                 print(filepath)
#
# ### But for this example, we will work with a single .dlis file specified in the cell below.  Note that there are some .dlis file formats that are not supported by DLISIO yet - good to catch them in a try except loop if you are reading files enmasse.

# %% [markdown]
# ### We will load a file from the open source Volve dataset available here: https://data.equinor.com/dataset/Volve

# %%
#filepath = r"G:\Sub_Appl_Data\WellDB\NO\wells\0008\NO 8-10-6 S\99.Miscellaneous\Well_reports\0003_Mudlogging_enclossures\MUD_LOG_1.DLIS"

# %% [markdown]
# ## Query for specific curve
#
# ### Very quickly you can use regex to find certain curves in a file (helpful if you are scanning a lot of files for certain curves)

# %%
filepath_list = []
curvename = []
units = []
descriptions = []

with dlisio.load(filepath) as file:
    for d in file:
        for channel in d.channels:
            curvename.append(channel.name)
            units.append(channel.unit)
            descriptions.append(channel.description)
            filepath_list.append(filepath)

# %% [markdown]
# ## Examining internal files and frames
#
# ### Keep in mind that dlis files can contain multiple files and multiple frames.  You can quickly get a numpy array of the curves in each frame below.

# %%
with dlisio.load(filepath) as file:
    print(file.describe())

# %%
with dlisio.load(filepath) as file:
    for d in file:
        for fram in d.frames:
            print(fram.curves())

# %% [markdown]
# ## Metadata including Origin information (well name and header)

# %%
with dlisio.load(filepath) as file:
    for d in file:
        print(d.describe())
        for fram in d.frames:
            print(fram.describe())
            for channel in d.channels:
                print(channel.describe())

# %%
with dlisio.load(filepath) as file:
    for d in file:
        for origin in d.origins:
            print(origin.describe())

# %% [markdown]
# ## Reading a full dlis file
#
# ### But most likely we want a single data frame of every curve, no matter which frame it came from.  So we write a bit more code to look through each frame, then look at each channel and get the curve name and unit information along with it.  We will also save the information about which internal file and which frame each curve resides in.

# %%
curves_L = []
curves_name = []
longs = []
unit = []
files_L = []
files_num = []
frames = []
frames_num = []
with dlisio.load(filepath) as file:
    for d in file:
        files_L.append(d)
        for fram in d.frames:
            frames.append(fram)
            for channel in d.channels:
                curves_name.append(channel.name)
                longs.append(channel.long_name)
                unit.append(channel.units)
                files_num.append(len(files_L))
                frames_num.append(len(frames))
                curves = channel.curves()
                curves_L.append(curves)

# %%
curve_index = pd.DataFrame(
{'Curve': curves_name,
'Long': longs,
'Unit': unit,
'Internal_File': files_num,
'Frame_Number': frames_num
})

# %%
curve_index

# %% [markdown]
# ## Creating a Pandas dataframe for the entire .dlis file
#
# ### We have to be careful creating a dataframe for the whole .dlis file as often there are some curves that represent mulitple values (numpy array of list values).  So, you can use something like:
#
# df = pd.DataFrame(data=curves_L, index=curves_name).T
#
# ### to view the full dlis file with lists as some of the curve values.
#
# ### Or we will use the code below to process each curve's 2D numpy array, stacking it if the curve contains multiple values per sample.  Then we convert each curve into its own dataframe (uniquifying the column names by adding a .1, .2, .3...etc).  Then, to preserve the order with the curve index above, append each data frame together in order to build the final dlis full dataframe.

# %%
def df_column_uniquify(df):
    df_columns = df.columns
    new_columns = []
    for item in df_columns:
        counter = 0
        newitem = item
        while newitem in new_columns:
            counter += 1
            newitem = "{}_{}".format(item, counter)
        new_columns.append(newitem)
    df.columns = new_columns
    return df

# %%
curve_df = pd.DataFrame()
name_index = 0
for c in curves_L:
    name = curves_name[name_index]
    np.vstack(c)
    try:
        num_col = c.shape[1]
        col_name = [name] * num_col
        df = pd.DataFrame(data=c, columns=col_name)
        name_index = name_index + 1
        df = df_column_uniquify(df)
        curve_df = pd.concat([curve_df, df], axis=1)
    except:
        num_col = 0
        df = pd.DataFrame(data=c, columns=[name])
        name_index = name_index + 1
        curve_df = pd.concat([curve_df, df], axis=1)
        continue

# %%
curve_df.head()

# %% [markdown]
# ### Then we can set the index and start making some plots.

# %%
curve_df = df_column_uniquify(curve_df)
#curve_df['DEPTH_Calc_ft'] = curve_df.loc[:,'TDEP'] * 0.0083333 #0.1 inch/12 inches per foot
curve_df = curve_df.set_index("DVER")
curve_df.index.names = [None]
curve_df = curve_df.replace(-999.25,np.nan)

# %%
curve_df.head()

# %%
curve_df.iloc[:,0:45].plot(kind='line',subplots=True, figsize=(10,100),grid=True, legend='reverse')

# %%
subset = curve_df.loc[:,['DEVI','DRHO']]

# %%
import plotly_express as px
px.line(subset, x='DEVI', y=None, range_y=[1500,0], width=500)

# %%
px.line(subset, x='DRHO', y=None, range_y=[1500,0], width=500)

# %% [markdown]
# # Hopefully that is enough code to get you started working with DLISIO.  There is much more functionality which can be accessed with help(dlisio)
